# %% [markdown]
# # Notebook for cleaning dataset

# %%
import pandas as pd
# Out:
# C:\Users\inesr\AppData\Local\Temp\ipykernel_23240\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('digitals_projects_tracker.csv')
data.head()
# Out:
#           Projet      Statut       Début  Fin prévue  Fin réelle  \
# 0    eBanking V1    En cours  2023-01-15  2024-01-15         NaN
# 1  Mobile App V2     Terminé  2022-05-10  2023-05-10  2023-05-12
# 2    eBanking V2  En attente  2024-02-01  2025-02-01         NaN
# 3    MIS Upgrade    En cours  2023-03-20  2024-03-20         NaN
# 4   Conformité 3     Terminé  2021-11-01  2022-11-01  2022-10-25
#
#    Budget prévu  Budget réel  Satisfaction client  Risque (%)  Délai (jours)  \
# 0       1000000     850000.0                 85.0          20            365
# 1        800000     900000.0                 90.0          30            370
# 2       1200000          NaN                  NaN          15            365
# 3        500000     350000.0                 75.0          25            365
# 4        450000     400000.0                 80.0          10            350
#
#    Temps passé (jours)  Personnes/jours (Effort)     Responsable  \
# 0                  633                       807     Jean Dupont
# 1                  367                      1227    Marie Martin
# 2                  251                      1247  Sophie Leclerc
# 3                  569                      1274     Paul Durand
# 4                  358                      1482   Alice Bernard
#
#       Département
# 0        eBanking
# 1  Mobile Banking
# 2      Conformité
# 3    Front Office
# 4             MIS

# %%
# Display data info on columns and data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Projet                    16 non-null     object
#  1   Statut                    16 non-null     object
#  2   Début                     16 non-null     object
#  3   Fin prévue                16 non-null     object
#  4   Fin réelle                5 non-null      object
#  5   Budget prévu              16 non-null     int64
#  6   Budget réel               11 non-null     float64
#  7   Satisfaction client       11 non-null     float64
#  8   Risque (%)                16 non-null     int64
#  9   Délai (jours)             16 non-null     int64
#  10  Temps passé (jours)       16 non-null     int64
#  11  Personnes/jours (Effort)  16 non-null     int64
#  12  Responsable               16 non-null     object
#  13  Département               16 non-null     object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.9+ KB

# %%
print(data.shape)
# Out:
# (16, 14)

# %%
# Missing values 
missing_values = data.isnull().sum()
missing_values
# Out:
# Projet                       0
# Statut                       0
# Début                        0
# Fin prévue                   0
# Fin réelle                  11
# Budget prévu                 0
# Budget réel                  5
# Satisfaction client          5
# Risque (%)                   0
# Délai (jours)                0
# Temps passé (jours)          0
# Personnes/jours (Effort)     0
# Responsable                  0
# Département                  0
# dtype: int64

# %%
# Display number of projects per status
print(data.value_counts("Statut"))
# Out:
# Statut
# En cours      7
# Terminé       5
# En attente    4
# Name: count, dtype: int64

# %%
# Transform Risque and satisfaction client column into percentage
data['Risque (%)'] = data['Risque (%)'] / 100
data['Satisfaction client'] = data['Satisfaction client'] / 100

# %%
# Adding the column budget_var: calculate the % of the gap
budget_var = round((data['Budget réel']- data['Budget prévu'])/data['Budget prévu'],3)
data.insert(loc=7, column='Budget gap', value = budget_var)
# Calculate the % of over budget
budget_over = data['Budget réel']/data['Budget prévu']
data.head()
# Out:
#           Projet      Statut       Début  Fin prévue  Fin réelle  \
# 0    eBanking V1    En cours  2023-01-15  2024-01-15         NaN
# 1  Mobile App V2     Terminé  2022-05-10  2023-05-10  2023-05-12
# 2    eBanking V2  En attente  2024-02-01  2025-02-01         NaN
# 3    MIS Upgrade    En cours  2023-03-20  2024-03-20         NaN
# 4   Conformité 3     Terminé  2021-11-01  2022-11-01  2022-10-25
#
#    Budget prévu  Budget réel  Budget gap  Satisfaction client  Risque (%)  \
# 0       1000000     850000.0      -0.150                 0.85        0.20
# 1        800000     900000.0       0.125                 0.90        0.30
# 2       1200000          NaN         NaN                  NaN        0.15
# 3        500000     350000.0      -0.300                 0.75        0.25
# 4        450000     400000.0      -0.111                 0.80        0.10
#
#    Délai (jours)  Temps passé (jours)  Personnes/jours (Effort)  \
# 0            365                  633                       807
# 1            370                  367                      1227
# 2            365                  251                      1247
# 3            365                  569                      1274
# 4            350                  358                      1482
#
#       Responsable     Département
# 0     Jean Dupont        eBanking
# 1    Marie Martin  Mobile Banking
# 2  Sophie Leclerc      Conformité
# 3     Paul Durand    Front Office
# 4   Alice Bernard             MIS

# %%
# Adding the column FTE (Personnes/jours // 220) ==> the number of working days 
data['FTE'] = data['Personnes/jours (Effort)'] / 220
data.drop(columns='Personnes/jours (Effort)', axis=1)
data.head()
# Out:
#           Projet      Statut       Début  Fin prévue  Fin réelle  \
# 0    eBanking V1    En cours  2023-01-15  2024-01-15         NaN
# 1  Mobile App V2     Terminé  2022-05-10  2023-05-10  2023-05-12
# 2    eBanking V2  En attente  2024-02-01  2025-02-01         NaN
# 3    MIS Upgrade    En cours  2023-03-20  2024-03-20         NaN
# 4   Conformité 3     Terminé  2021-11-01  2022-11-01  2022-10-25
#
#    Budget prévu  Budget réel  Budget gap  Satisfaction client  Risque (%)  \
# 0       1000000     850000.0      -0.150                 0.85        0.20
# 1        800000     900000.0       0.125                 0.90        0.30
# 2       1200000          NaN         NaN                  NaN        0.15
# 3        500000     350000.0      -0.300                 0.75        0.25
# 4        450000     400000.0      -0.111                 0.80        0.10
#
#    Délai (jours)  Temps passé (jours)  Personnes/jours (Effort)  \
# 0            365                  633                       807
# 1            370                  367                      1227
# 2            365                  251                      1247
# 3            365                  569                      1274
# 4            350                  358                      1482
#
#       Responsable     Département       FTE
# 0     Jean Dupont        eBanking  3.668182
# 1    Marie Martin  Mobile Banking  5.577273
# 2  Sophie Leclerc      Conformité  5.668182
# 3     Paul Durand    Front Office  5.790909
# 4   Alice Bernard             MIS  6.736364

# %%
# Save as an excel file
data.to_excel('digitals_projects_tracker.xlsx', index = False)

# %%
data
# Out:
#                   Projet      Statut       Début  Fin prévue  Fin réelle  \
# 0            eBanking V1    En cours  2023-01-15  2024-01-15         NaN
# 1          Mobile App V2     Terminé  2022-05-10  2023-05-10  2023-05-12
# 2            eBanking V2  En attente  2024-02-01  2025-02-01         NaN
# 3            MIS Upgrade    En cours  2023-03-20  2024-03-20         NaN
# 4           Conformité 3     Terminé  2021-11-01  2022-11-01  2022-10-25
# 5          Risque Banque    En cours  2023-06-01  2024-06-01         NaN
# 6        Front Office V1    En cours  2023-02-10  2024-02-10         NaN
# 7      Helpdesk eBanking  En attente  2024-05-01  2025-05-01         NaN
# 8          Mobile App V3     Terminé  2022-08-05  2023-08-05  2023-08-03
# 9   Backend Optimisation     Terminé  2022-03-15  2023-03-15  2023-03-10
# 10    Compliance Upgrade    En cours  2023-09-25  2024-09-25         NaN
# 11   Ressources Humaines  En attente  2024-01-10  2025-01-10         NaN
# 12       Front Office V2     Terminé  2022-11-20  2023-11-20  2023-11-15
# 13          Conformité 4  En attente  2024-06-01  2025-06-01         NaN
# 14         Mobile App V4    En cours  2023-07-15  2024-07-15         NaN
# 15                DevOps    En cours  2023-10-15  2025-01-31         NaN
#
#     Budget prévu  Budget réel  Budget gap  Satisfaction client  Risque (%)  \
# 0        1000000     850000.0      -0.150                 0.85        0.20
# 1         800000     900000.0       0.125                 0.90        0.30
# 2        1200000          NaN         NaN                  NaN        0.15
# 3         500000     350000.0      -0.300                 0.75        0.25
# 4         450000     400000.0      -0.111                 0.80        0.10
# 5         900000     750000.0      -0.167                 0.70        0.35
# 6         600000     400000.0      -0.333                 0.80        0.40
# 7        1300000          NaN         NaN                  NaN        0.18
# 8         750000     800000.0       0.067                 0.88        0.28
# 9         550000     500000.0      -0.091                 0.85        0.22
# 10       1100000          NaN         NaN                  NaN        0.30
# 11       1500000          NaN         NaN                  NaN        0.25
# 12        620000     600000.0      -0.032                 0.82        0.15
# 13       1400000          NaN         NaN                  NaN        0.20
# 14        980000     950000.0      -0.031                 0.78        0.18
# 15        550000     750050.0       0.364                 0.65        0.33
#
#     Délai (jours)  Temps passé (jours)  Personnes/jours (Effort)  \
# 0             365                  633                       807
# 1             370                  367                      1227
# 2             365                  251                      1247
# 3             365                  569                      1274
# 4             350                  358                      1482
# 5             365                  496                       873
# 6             365                  607                       742
# 7             365                  161                       799
# 8             365                  363                      1017
# 9             365                  360                       868
# 10            365                  380                      1499
# 11            365                  273                      1011
# 12            365                  360                       653
# 13            365                  130                      1221
# 14            365                  452                       695
# 15            474                  114                       455
#
#          Responsable          Département       FTE
# 0        Jean Dupont             eBanking  3.668182
# 1       Marie Martin       Mobile Banking  5.577273
# 2     Sophie Leclerc           Conformité  5.668182
# 3        Paul Durand         Front Office  5.790909
# 4      Alice Bernard                  MIS  6.736364
# 5      Thomas Girard       Support Client  3.968182
# 6        Laura Petit  Ressources Humaines  3.372727
# 7     Antoine Robert           Opérations  3.631818
# 8       Claire Faure              Risques  4.622727
# 9      Julien Moreau        Communication  3.945455
# 10  Isabelle Lefèvre         Front Office  6.813636
# 11   Vincent Lambert           Conformité  4.595455
# 12      Julie Perrin  Ressources Humaines  2.968182
# 13   Nicolas Rolland             eBanking  5.550000
# 14    Emilie Garnier       Mobile Banking  3.159091
# 15   Natalie Sanchez                  MIS  2.068182
